# %% [markdown]
# # Goal
#
# This notebook checks model generalization performance on other dsets.
#
# **With gratitude to**:
# - https://github.com/mattiaspaul/OBELISK
# -  https://github.com/kbressem/faimed3d/blob/main/examples/3d_segmentation.md

# %%
import os

try:
    taskid = int(os.getenv('SLURM_ARRAY_TASK_ID'))
    do_task = True
except:
    taskid = 0
    do_task = False

import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

# %load_ext autoreload
# %autoreload 2

from pathlib import Path

import SimpleITK as sitk
import pandas as pd
import numpy as np

import seaborn as sns

from fastai              import *
from fastai.torch_basics import *
from fastai.basics       import *
from fastai.distributed  import *

# Learner
import gc
gc.collect()

from helpers.losses                import dice_score
from helpers.items_constants       import *
from helpers.transforms_simplified import *
from helpers.general            import rm_prefix, get_param, get_param_default,rm_prefix, modelfn2dict, torch2sitk, sitk2torch
from helpers.model_loss_choices import get_model, get_loss
from helpers.preprocess         import batch_get_bbox
from helpers.postprocess        import get_largest_connected_component, eval_measure, eval_lcc
# Out:
# cuda:0

# %%
# POST LCC DF DICT

# Items as dict 
from pathlib import Path
from helpers.items_constants import *

#items  = all_test_lbl_items
items = all_test_lbl_items #ppmi, icmb, adni, aibl, abvib, test_items
itemsd = getd(items)

def is_recent(model_fn):
    dates = [f"Aug_0{x}"  for x in range(3,10)]
    dates += [f"Aug_1{x}" for x in range(0,10)]
    dates += [f"Aug_2{x}" for x in range(0,10)]
    dates += [f"Aug_3{x}" for x in range(0,10)]
    dates += [f"Sep_0{x}" for x in range(0,10)]
    return any([date in str(model_fn) for date in dates])


model_fns = sorted(Path(run_src).iterdir(), key=os.path.getmtime, reverse=True)

done = [str(model_fn) 
        for model_fn in model_fns 
        if os.path.isfile(f"{str(model_fn)}/post_lcc_df.pkl") and is_recent(model_fn)
       ]
#print(*rm_prefix(done, prefix=run_src, do_sort=True), sep="\n")
print(f"DONE: {len(done)}")

post_df_dict = {}

for done_fn in done:
    model_name = Path(done_fn).name
    #print(model_name)
    model_src = f"{run_src}/{model_name}"
    check_post_df  = pd.read_pickle(f"{model_src}/post_lcc_df.pkl")
    check_pre_df   = pd.read_pickle(f"{model_src}/pre_lcc_df.pkl")
    #check_stats_df = pd.read_pickle(f"{model_src}/stats_df.pkl")
    
    #check_stats_df = check_stats_df.style.set_caption(f"{model_name}")

    post_df_dict[model_name] = check_post_df
    
    if len(check_post_df) != len(itemsd):
        print(done_fn)
        print("Len", len(check_post_df))
        print("*" * 50)
    #display(check_post_df)
    #display(check_pre_df)
    #display(check_stats_df)
# Out:
# DONE: 308

# %%
# POST PROCESS OBELISK 144 BACK TO 1.5 voxel spacing and center crop to 96

# convert preds => bilinear interpolation of probabilities
from monai.transforms import Compose, Spacingd, CenterSpatialCropd
convert_to_96_tfms = Compose([
    Spacingd(keys=["pred"], pixdim=(1.5,1.5,1.5), mode=("bilinear")),
    CenterSpatialCropd(keys=["pred"], roi_size=(96, 96, 96))
])

# REDO OBELISKS
obelisk_144 = [str(model_fn) 
        for model_fn in model_fns 
        if (("OBELISK" in str(model_fn) and "full_res_144_pixdim_1.0" in str(model_fn)) and \
                (os.path.isfile(f"{str(model_fn)}/preds_batch_96_bs_5.pkl")) and \
                (not os.path.isfile(f"{str(model_fn)}/to_96_preds_batch_96_bs_5.pkl")) and \
                (os.path.isfile(f"{str(model_fn)}/figs/metrics.png")) and \
                is_recent(model_fn)
            )
       ]

print(len(obelisk_144), *obelisk_144[0:5], sep="\n")
# Out:
# 2
# /gpfs/data/oermannlab/private_data/DeepPit/runs/model_OBELISKHYBRID_loss_DICE_loss_full_res_144_pixdim_1.0_do_simple_True_do_flip_True_bs_2_epochs_60_time_1629303640_Wed_Aug_18_2021_hr_12_min_20
# /gpfs/data/oermannlab/private_data/DeepPit/runs/model_OBELISKHYBRID_loss_BCE_loss_full_res_144_pixdim_1.0_do_simple_True_do_flip_True_bs_2_epochs_60_time_1629304756_Wed_Aug_18_2021_hr_12_min_39

# %%
done = [model_fn 
        for model_fn in obelisk_144 
        if os.path.isfile(f"{str(model_fn)}/to_96_preds_batch_96_bs_5.pkl")
       ]
print(len(done), *done[0:5], sep="\n")
# Out:
# 0

# %%
# doing    
model_idx  = taskid
model_fn   = obelisk_144[model_idx]

print(f"Doing: {model_fn}")
# Out:
# Doing: /gpfs/data/oermannlab/private_data/DeepPit/runs/model_OBELISKHYBRID_loss_DICE_loss_full_res_144_pixdim_1.0_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628029376_Tue_Aug_03_2021_hr_18_min_22

# %%
# create batches
bs        = 5
batches = [itemsd[i:min(i+bs, len(itemsd))] for i in range(0,len(itemsd),bs)]
ranges  = [range(i,min(i+bs, len(itemsd))) for i in range(0,len(itemsd),bs)]

# 2min per OBELISK
start = time.time()

model_name = Path(model_fn).name
print(model_name)

for i in range(len(batches)):
    #start2 = time.time()
    
    # open pixdim 1.0, full_res 144 preds
    with open(f"{run_src}/{model_name}/preds_batch_{i}_bs_{bs}.pkl", 'rb') as handle:
        preds_144 = pickle.load(handle)

    # transform to pixdim 1.5 full_res 96 preds
    preds_96 = convert_to_96_tfms([{"pred": pred} for pred in preds_144])

    with open(f"{run_src}/{model_name}/to_96_preds_batch_{i}_bs_{bs}.pkl", 'wb') as handle:
        pickle.dump([torch.tensor(d["pred"]) for d in preds_96], handle)

    #print(preds_144[0].shape, preds_96[0]["pred"].shape, len(preds_96))
    #elapsed2 = time.time() - start2
    #print(f"Elapsed: {elapsed2:0.2f} s.")

elapsed = time.time() - start
print(f"Elapsed: {elapsed:0.2f} s.")
# Out:
# model_OBELISKHYBRID_loss_DICE_loss_full_res_144_pixdim_1.0_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628029376_Tue_Aug_03_2021_hr_18_min_22
# Elapsed: 1.19 s.
# Elapsed: 1.19 s.
# Elapsed: 1.16 s.
# Elapsed: 1.19 s.
# Elapsed: 1.19 s.
# Elapsed: 1.33 s.
# Elapsed: 1.20 s.
# Elapsed: 1.20 s.
# Elapsed: 1.30 s.
# Elapsed: 1.12 s.
# Elapsed: 1.21 s.
# Elapsed: 1.17 s.
# Elapsed: 1.09 s.
# Elapsed: 1.21 s.
# Elapsed: 1.17 s.
# Elapsed: 1.22 s.
# Elapsed: 1.12 s.
# Elapsed: 1.10 s.
# Elapsed: 1.13 s.
# Elapsed: 1.19 s.
# Elapsed: 1.10 s.
# Elapsed: 1.22 s.
# Elapsed: 1.08 s.
# Elapsed: 1.25 s.
# Elapsed: 1.21 s.
# Elapsed: 1.25 s.
# Elapsed: 1.28 s.
# Elapsed: 1.22 s.
# Elapsed: 1.08 s.
# Elapsed: 1.12 s.
# Elapsed: 1.06 s.
# Elapsed: 1.13 s.
# Elapsed: 1.11 s.
# Elapsed: 1.16 s.
# Elapsed: 1.29 s.
# Elapsed: 1.12 s.
# Elapsed: 1.26 s.
# Elapsed: 1.25 s.
# Elapsed: 1.13 s.
# Elapsed: 1.31 s.
# Elapsed: 1.22 s.
# Elapsed: 1.10 s.
# Elapsed: 1.10 s.
# Elapsed: 1.13 s.
# Elapsed: 1.20 s.
# Elapsed: 1.12 s.
# Elapsed: 1.25 s.
# Elapsed: 1.12 s.
# Elapsed: 1.18 s.
# Elapsed: 1.16 s.
# Elapsed: 1.11 s.
# Elapsed: 1.10 s.
# Elapsed: 1.27 s.
# Elapsed: 1.20 s.
# Elapsed: 1.21 s.
# Elapsed: 1.09 s.
# Elapsed: 1.09 s.
# Elapsed: 1.33 s.
# Elapsed: 1.21 s.
# Elapsed: 1.24 s.
# Elapsed: 1.08 s.
# Elapsed: 1.36 s.
# Elapsed: 1.25 s.
# Elapsed: 1.00 s.
# Elapsed: 1.15 s.
# Elapsed: 1.16 s.
# Elapsed: 1.10 s.
# Elapsed: 1.10 s.
# Elapsed: 1.15 s.
# Elapsed: 1.26 s.
# Elapsed: 1.23 s.
# Elapsed: 1.27 s.
# Elapsed: 1.20 s.
# Elapsed: 1.25 s.
# Elapsed: 1.16 s.
# Elapsed: 1.26 s.
# Elapsed: 1.17 s.
# Elapsed: 1.20 s.
# Elapsed: 1.21 s.
# Elapsed: 1.00 s.
# Elapsed: 1.18 s.
# Elapsed: 1.13 s.
# Elapsed: 1.34 s.
# Elapsed: 1.18 s.
# Elapsed: 1.30 s.
# Elapsed: 1.32 s.
# Elapsed: 1.36 s.
# Elapsed: 1.13 s.
# Elapsed: 1.19 s.
# Elapsed: 1.34 s.
# Elapsed: 1.21 s.
# Elapsed: 1.19 s.
# Elapsed: 1.26 s.
# Elapsed: 1.11 s.
# Elapsed: 1.27 s.
# Elapsed: 1.23 s.
# Elapsed: 0.86 s.
# Elapsed: 114.96 s.

# %%
# not all obelisk have predictions
# for i,model_fn in enumerate(obelisk_144):
#     print(i, model_fn); print("*"*50);
#     print("N files: ", len(os.listdir(model_fn))); print("*"*50);
#     #print(os.listdir(model_fn))
# Out:
# model_CONDSEG_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628202024_Thu_Aug_05_2021_hr_18_min_20
# model_CONDSEG_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628493195_Mon_Aug_09_2021_hr_03_min_13
# model_CONDSEG_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628562710_Mon_Aug_09_2021_hr_22_min_31
# model_CONDSEG_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628097978_Wed_Aug_04_2021_hr_13_min_26
# model_CONDSEG_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628199814_Thu_Aug_05_2021_hr_17_min_43
# model_CONDSEG_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628302341_Fri_Aug_06_2021_hr_22_min_12
# model_CONDSEG_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628426611_Sun_Aug_08_2021_hr_08_min_43
# model_CONDSEG_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628447015_Sun_Aug_08_2021_hr_14_min_23
# model_CONDSEG_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628490587_Mon_Aug_09_2021_hr_02_min_29
# model_CONDSEG_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628562656_Mon_Aug_09_2021_hr_22_min_30
# model_CONDSEG_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628200115_Thu_Aug_05_2021_hr_17_min_48
# model_CONDSEG_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628426611_Sun_Aug_08_2021_hr_08_min_43
# model_CONDSEG_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628097973_Wed_Aug_04_2021_hr_13_min_26
# model_CONDSEG_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628200038_Thu_Aug_05_2021_hr_17_min_47
# model_CONDSEG_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628295793_Fri_Aug_06_2021_hr_20_min_23
# model_CONDSEG_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628426610_Sun_Aug_08_2021_hr_08_min_43
# model_CONDSEG_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628446380_Sun_Aug_08_2021_hr_14_min_13
# model_CONDSEG_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628560951_Mon_Aug_09_2021_hr_22_min_02
# model_CONDSEG_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628658906_Wed_Aug_11_2021_hr_01_min_15
# model_OBELISKHYBRID_loss_BCE_loss_full_res_144_pixdim_1.0_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628028627_Tue_Aug_03_2021_hr_18_min_10
# model_OBELISKHYBRID_loss_BCE_loss_full_res_144_pixdim_1.0_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628415289_Sun_Aug_08_2021_hr_05_min_34
# model_OBELISKHYBRID_loss_BCE_loss_full_res_144_pixdim_1.0_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628520424_Mon_Aug_09_2021_hr_10_min_47
# model_OBELISKHYBRID_loss_BCE_loss_full_res_144_pixdim_1.0_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628588199_Tue_Aug_10_2021_hr_05_min_36
# model_OBELISKHYBRID_loss_BCE_loss_full_res_144_pixdim_1.0_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628686957_Wed_Aug_11_2021_hr_09_min_02
# model_OBELISKHYBRID_loss_BCE_loss_full_res_144_pixdim_1.0_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628117760_Wed_Aug_04_2021_hr_18_min_56
# model_OBELISKHYBRID_loss_BCE_loss_full_res_144_pixdim_1.0_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628312574_Sat_Aug_07_2021_hr_01_min_02
# model_OBELISKHYBRID_loss_BCE_loss_full_res_144_pixdim_1.0_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628313534_Sat_Aug_07_2021_hr_01_min_18
# model_OBELISKHYBRID_loss_BCE_loss_full_res_144_pixdim_1.0_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628413134_Sun_Aug_08_2021_hr_04_min_58
# model_OBELISKHYBRID_loss_BCE_loss_full_res_144_pixdim_1.0_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628587053_Tue_Aug_10_2021_hr_05_min_17
# model_OBELISKHYBRID_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628011517_Tue_Aug_03_2021_hr_13_min_25
# model_OBELISKHYBRID_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628407381_Sun_Aug_08_2021_hr_03_min_23
# model_OBELISKHYBRID_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628504159_Mon_Aug_09_2021_hr_06_min_15
# model_OBELISKHYBRID_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628572458_Tue_Aug_10_2021_hr_01_min_14
# model_OBELISKHYBRID_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628670628_Wed_Aug_11_2021_hr_04_min_30
# model_OBELISKHYBRID_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1627963631_Tue_Aug_03_2021_hr_00_min_07
# model_OBELISKHYBRID_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1627964070_Tue_Aug_03_2021_hr_00_min_14
# model_OBELISKHYBRID_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628303428_Fri_Aug_06_2021_hr_22_min_30
# model_OBELISKHYBRID_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628303483_Fri_Aug_06_2021_hr_22_min_31
# model_OBELISKHYBRID_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628405192_Sun_Aug_08_2021_hr_02_min_46
# model_OBELISKHYBRID_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628457592_Sun_Aug_08_2021_hr_17_min_19
# model_OBELISKHYBRID_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628500855_Mon_Aug_09_2021_hr_05_min_20
# model_OBELISKHYBRID_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628669942_Wed_Aug_11_2021_hr_04_min_19
# model_OBELISKHYBRID_loss_DICE_loss_full_res_144_pixdim_1.0_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628029376_Tue_Aug_03_2021_hr_18_min_22
# model_OBELISKHYBRID_loss_DICE_loss_full_res_144_pixdim_1.0_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628412487_Sun_Aug_08_2021_hr_04_min_48
# model_OBELISKHYBRID_loss_DICE_loss_full_res_144_pixdim_1.0_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628586305_Tue_Aug_10_2021_hr_05_min_05
# model_OBELISKHYBRID_loss_DICE_loss_full_res_144_pixdim_1.0_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628685545_Wed_Aug_11_2021_hr_08_min_39
# model_OBELISKHYBRID_loss_DICE_loss_full_res_144_pixdim_1.0_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628117846_Wed_Aug_04_2021_hr_18_min_57
# model_OBELISKHYBRID_loss_DICE_loss_full_res_144_pixdim_1.0_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628310872_Sat_Aug_07_2021_hr_00_min_34
# model_OBELISKHYBRID_loss_DICE_loss_full_res_144_pixdim_1.0_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628310908_Sat_Aug_07_2021_hr_00_min_35
# model_OBELISKHYBRID_loss_DICE_loss_full_res_144_pixdim_1.0_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628411740_Sun_Aug_08_2021_hr_04_min_35
# model_OBELISKHYBRID_loss_DICE_loss_full_res_144_pixdim_1.0_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628584593_Tue_Aug_10_2021_hr_04_min_36
# model_OBELISKHYBRID_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628011517_Tue_Aug_03_2021_hr_13_min_25
# model_OBELISKHYBRID_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628405179_Sun_Aug_08_2021_hr_02_min_46
# model_OBELISKHYBRID_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628500850_Mon_Aug_09_2021_hr_05_min_20
# model_OBELISKHYBRID_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628571918_Tue_Aug_10_2021_hr_01_min_05
# model_OBELISKHYBRID_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1627963440_Tue_Aug_03_2021_hr_00_min_04
# model_OBELISKHYBRID_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1627964080_Tue_Aug_03_2021_hr_00_min_14
# model_OBELISKHYBRID_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628306188_Fri_Aug_06_2021_hr_23_min_16
# model_OBELISKHYBRID_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628404361_Sun_Aug_08_2021_hr_02_min_32
# model_OBELISKHYBRID_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628436691_Sun_Aug_08_2021_hr_11_min_31
# model_OBELISKHYBRID_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628497551_Mon_Aug_09_2021_hr_04_min_25
# model_UNET3D_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628008844_Tue_Aug_03_2021_hr_12_min_40
# model_UNET3D_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628390969_Sat_Aug_07_2021_hr_22_min_49
# model_UNET3D_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1627970860_Tue_Aug_03_2021_hr_02_min_07
# model_UNET3D_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1627971506_Tue_Aug_03_2021_hr_02_min_18
# model_UNET3D_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628288968_Fri_Aug_06_2021_hr_18_min_29
# model_UNET3D_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628389599_Sat_Aug_07_2021_hr_22_min_26
# model_UNET3D_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628007881_Tue_Aug_03_2021_hr_12_min_24
# model_UNET3D_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628389599_Sat_Aug_07_2021_hr_22_min_26
# model_UNET3D_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1627970836_Tue_Aug_03_2021_hr_02_min_07
# model_UNET3D_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1627971508_Tue_Aug_03_2021_hr_02_min_18
# model_UNET3D_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628288968_Fri_Aug_06_2021_hr_18_min_29
# model_UNET3D_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628389599_Sat_Aug_07_2021_hr_22_min_26
# model_UNETR_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628124575_Wed_Aug_04_2021_hr_20_min_49
# model_UNETR_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628427043_Sun_Aug_08_2021_hr_08_min_50
# model_UNETR_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628485066_Mon_Aug_09_2021_hr_00_min_57
# model_UNETR_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628555571_Mon_Aug_09_2021_hr_20_min_32
# model_UNETR_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_False_bs_2_epochs_60_time_1628028739_Tue_Aug_03_2021_hr_18_min_12
# model_UNETR_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628483131_Mon_Aug_09_2021_hr_00_min_25
# model_UNETR_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628651501_Tue_Aug_10_2021_hr_23_min_11
# model_UNETR_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628014748_Tue_Aug_03_2021_hr_14_min_19
# model_UNETR_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628457269_Sun_Aug_08_2021_hr_17_min_14
# model_UNETR_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628472902_Sun_Aug_08_2021_hr_21_min_35
# model_UNETR_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628481680_Mon_Aug_09_2021_hr_00_min_01
# model_UNETR_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628531252_Mon_Aug_09_2021_hr_13_min_47
# model_UNETR_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628554750_Mon_Aug_09_2021_hr_20_min_19
# model_UNETR_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628651501_Tue_Aug_10_2021_hr_23_min_11
# model_UNETR_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628683844_Wed_Aug_11_2021_hr_08_min_10
# model_UNETR_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_False_bs_2_epochs_60_time_1628008122_Tue_Aug_03_2021_hr_12_min_28
# model_UNETR_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628480080_Sun_Aug_08_2021_hr_23_min_34
# model_UNETR_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628554005_Mon_Aug_09_2021_hr_20_min_06
# model_UNETR_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628651501_Tue_Aug_10_2021_hr_23_min_11
# model_VNET_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628011463_Tue_Aug_03_2021_hr_13_min_24
# model_VNET_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628398922_Sun_Aug_08_2021_hr_01_min_02
# model_VNET_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628579841_Tue_Aug_10_2021_hr_03_min_17
# model_VNET_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628678580_Wed_Aug_11_2021_hr_06_min_43
# model_VNET_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1627978233_Tue_Aug_03_2021_hr_04_min_10
# model_VNET_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1627978855_Tue_Aug_03_2021_hr_04_min_20
# model_VNET_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628294473_Fri_Aug_06_2021_hr_20_min_01
# model_VNET_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628295674_Fri_Aug_06_2021_hr_20_min_21
# model_VNET_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628397477_Sun_Aug_08_2021_hr_00_min_37
# model_VNET_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628465251_Sun_Aug_08_2021_hr_19_min_27
# model_VNET_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628578641_Tue_Aug_10_2021_hr_02_min_57
# model_VNET_loss_BCE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628677940_Wed_Aug_11_2021_hr_06_min_32
# model_VNET_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628010897_Tue_Aug_03_2021_hr_13_min_14
# model_VNET_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628396695_Sun_Aug_08_2021_hr_00_min_24
# model_VNET_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628508029_Mon_Aug_09_2021_hr_07_min_20
# model_VNET_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_False_do_flip_True_bs_2_epochs_60_time_1628578584_Tue_Aug_10_2021_hr_02_min_56
# model_VNET_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1627978137_Tue_Aug_03_2021_hr_04_min_08
# model_VNET_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1627978943_Tue_Aug_03_2021_hr_04_min_22
# model_VNET_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628295793_Fri_Aug_06_2021_hr_20_min_23
# model_VNET_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628396669_Sun_Aug_08_2021_hr_00_min_24
# model_VNET_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628463798_Sun_Aug_08_2021_hr_19_min_03
# model_VNET_loss_DICE_loss_full_res_96_pixdim_1.5_do_simple_True_do_flip_True_bs_2_epochs_60_time_1628577004_Tue_Aug_10_2021_hr_02_min_30

# %%
print("Done")

# %% [markdown]
# # End
