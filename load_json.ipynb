# %%
import json

with open('resultsVaryingFixedObj.json', 'r') as handle:
    parsed = json.load(handle)
    

print(json.dumps(parsed, indent=4, sort_keys=True))
# Out:
# {
#     "50455": {
#         "bbox_coords": [
#             79.0,
#             109.0,
#             112.0,
#             140.0,
#             106.0,
#             128.0
#         ],
#         "coverage": 0.5277542629096625,
#         "dice": 0.5905077636074557
#     },
#     "50457": {
#         "bbox_coords": [
#             78.0,
#             107.0,
#             114.0,
#             138.0,
#             119.0,
#             138.0
#         ],
#         "coverage": 0.824746385494049,
#         "dice": 0.8248452166966247
#     },
#     "50458": {
#         "bbox_coords": [
#             78.0,
#             106.0,
#             119.0,
#             144.0,
#             101.0,
#             120.0
#         ],
#         "coverage": 0.804550415582235,
#         "dice": 0.8078738829876918
#     },
#     "50459": {
#         "bbox_coords": [
#             80.0,
#             108.0,
#             113.0,
#             138.0,
#             104.0,
#             124.0
#         ],
# ...

# %%
parsed
# Out:
# {'fixed': '50456',
#  '50455': {'dice': 0.5905077636074557,
#   'coverage': 0.5277542629096625,
#   'bbox_coords': [79.0, 109.0, 112.0, 140.0, 106.0, 128.0]},
#  '50458': {'dice': 0.8078738829876918,
#   'coverage': 0.804550415582235,
#   'bbox_coords': [78.0, 106.0, 119.0, 144.0, 101.0, 120.0]},
#  '50461': {'dice': 0.7226850521880686,
#   'coverage': 0.7355033622453951,
#   'bbox_coords': [80.0, 108.0, 118.0, 142.0, 118.0, 138.0]},
#  '50463': {'dice': 0.8292789671395747,
#   'coverage': 0.7462422054479816,
#   'bbox_coords': [80.0, 109.0, 119.0, 146.0, 114.0, 135.0]},
#  '50459': {'dice': 0.7393492648515833,
#   'coverage': 0.6857310887304271,
#   'bbox_coords': [80.0, 108.0, 113.0, 138.0, 104.0, 124.0]},
#  '50457': {'dice': 0.8248452166966247,
#   'coverage': 0.824746385494049,
#   'bbox_coords': [78.0, 107.0, 114.0, 138.0, 119.0, 138.0]},
#  '50462': {'dice': 0.8260695079861947,
#   'coverage': 0.8168902293832844,
#   'bbox_coords': [79.0, 107.0, 120.0, 144.0, 114.0, 133.0]},
# ...
